# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
names = ['en','sv','de','fr','nl','ru','it','es','pl','vi']
xls = pd.ExcelFile('wikimed top100 stats.xlsx')
for name in names:
    df = pd.read_excel(xls,sheet_name=name)
    if name=='en':
        df.columns = df.iloc[0]
        df.drop(0,axis=0,inplace=True)
        colnames = df[df.columns[0]]
        df = df.T
        df.columns = colnames
        df = df.iloc[1:]
        df.to_excel(name+'.xlsx')
    else:
        df.drop('Title',axis=1,inplace=True)
        colnames = df[df.columns[0]]
        df = df.T
        df.columns = colnames
        df = df.iloc[1:]
        df.to_excel(name+'.xlsx')

# %%
global_daysum = []
for name in names:
# name=names[0]
    df = pd.read_excel(name+'.xlsx')
    npdf = np.array(df[df.columns[1:]])
    npdf_daysum = np.sum(npdf,axis=-1)
    df_daynorm = pd.DataFrame(100*np.apply_along_axis(np.divide,0,npdf,npdf_daysum))
    df_daynorm.columns = df.columns[1:]
    df_daynorm.index = df[df.columns[0]]
    df_daynorm.to_excel('daynorm/'+name+'_daynorm.xlsx')
    global_daysum.append([name,npdf_daysum])

# %%
df_global_daysum = pd.DataFrame(np.vstack([i[1] for i in global_daysum]))
df_global_daysum = df_global_daysum.T
df_global_daysum.columns = [i[0] for i in global_daysum]
df_global_daysum.index = df[df.columns[0]]
df_global_daysum.to_excel('daynorm/global_daysum.xlsx')

plt.figure(figsize=(5,3),dpi=600)
for name in names:
    plt.plot(df_global_daysum.index,df_global_daysum[name].rolling(window=30).mean(),label=name)
plt.legend(bbox_to_anchor=(0,0,1.2,0.95))
plt.ylabel('Count')
plt.xlabel('Dates')
plt.savefig('daysums.png')

df_global_daysum_ = df_global_daysum.loc[df_global_daysum.index>datetime.datetime(2019,9,1)]
plt.figure(figsize=(5,3),dpi=600)
for name in names:
    plt.plot(df_global_daysum_.index,df_global_daysum_[name].rolling(window=30).mean(),label=name)
plt.legend(bbox_to_anchor=(0,0,1.2,0.95))
plt.ylabel('Count')
plt.xlabel('Dates')
plt.savefig('daysums_september2019.png')

# %%
# plt.figure(figsize=(5,3),dpi=600)
# for name in names:
#     plt.plot(df_global_daysum.index,df_global_daysum[name].rolling(window=30).mean(),label=name)
# plt.legend(bbox_to_anchor=(0,0,1.2,0.95))
# plt.ylabel('Count')
# plt.xlabel('Dates')
# plt.savefig('daysums.png')


plt.figure(figsize=(5,3),dpi=600)
for year in [2015,2016,2017,2018,2019]:
    df_global_daysum_ = df_global_daysum.loc[(df_global_daysum.index>=datetime.datetime(year,1,1))&(df_global_daysum.index<datetime.datetime(year+1,1,1))]
    plt.plot([datetime.datetime(2019,1,1)+datetime.timedelta(days=int(_)-10) for _ in np.arange(len(df_global_daysum_))],df_global_daysum_['en'].rolling(window=30).mean(),label=year)
plt.legend(bbox_to_anchor=(0,0,1.3,0.75))
plt.ylabel('Count')
plt.xlabel('Days since beginning of the year')
plt.savefig('daysums_byyear_en.png')

# df_global_daysum.to_excel('daynorm/global_daysum.xlsx')

# # plt.plot(df_daynorm.index,np.sum(npdf,axis=-1))
# # # df_daynorm.Coronavirus.sum()
# # # df_daynorm.loc[df_daynorm.index>datetime.datetime(2020,1,1)].Coronavirus.plot()

# %%
df[df.columns[0]]
# Out:
# 0      2015-07-01
# 1      2015-07-02
# 2      2015-07-03
# 3      2015-07-04
# 4      2015-07-05
#           ...
# 1897   2020-09-09
# 1898   2020-09-10
# 1899   2020-09-11
# 1900   2020-09-12
# 1901   2020-09-13
# Name: Unnamed: 0, Length: 1902, dtype: datetime64[ns]

# %%
pd.DataFrame(np.apply_along_axis(np.divide,0,npdf,np.sum(npdf,axis=-1)))
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.000791  0.022451  0.000285  0.008449  0.015084  0.023587  0.114220
# 1     0.000918  0.021639  0.000328  0.008578  0.014903  0.022454  0.055779
# 2     0.000913  0.026476  0.000375  0.008141  0.015560  0.035747  0.048449
# 3     0.000657  0.027647  0.000371  0.007622  0.015401  0.050438  0.043421
# 4     0.000616  0.027435  0.000340  0.012910  0.017876  0.046700  0.052732
# ...        ...       ...       ...       ...       ...       ...       ...
# 1897  0.025121  0.019875  0.028990  0.017708  0.016865  0.016359  0.027410
# 1898  0.025310  0.019679  0.031608  0.016615  0.017145  0.013736  0.018351
# 1899  0.025635  0.019068  0.030756  0.015416  0.015267  0.014554  0.010942
# 1900  0.023131  0.020276  0.030289  0.014914  0.013212  0.015273  0.010444
# 1901  0.025963  0.019269  0.030919  0.016548  0.014163  0.014661  0.010353
#
#             7         8         9   ...        90        91        92  \
# 0     0.012882  0.016000  0.000000  ...  0.000951  0.006137  0.007301
# 1     0.013061  0.015969  0.000000  ...  0.072529  0.006237  0.007593
# 2     0.014354  0.015865  0.000000  ...  0.001113  0.006299  0.007419
# 3     0.013403  0.017005  0.000000  ...  0.001041  0.006360  0.007443
# 4     0.013976  0.016992  0.000000  ...  0.001047  0.006229  0.008147
# ...        ...       ...       ...  ...       ...       ...       ...
# 1897  0.009473  0.012187  0.044908  ...  0.004047  0.005945  0.005884
# 1898  0.009116  0.012185  0.044563  ...  0.003579  0.005937  0.005771
# 1899  0.009745  0.012336  0.042675  ...  0.004304  0.006216  0.005151
# 1900  0.009685  0.012629  0.040323  ...  0.004233  0.011379  0.005597
# 1901  0.011303  0.012949  0.042003  ...  0.004464  0.007036  0.007005
#
#             93        94        95        96        97        98        99
# 0     0.007457  0.005979  0.008293  0.007980  0.005280  0.021083  0.000002
# 1     0.007661  0.006337  0.008881  0.008083  0.005275  0.009742  0.000000
# 2     0.008359  0.010242  0.009081  0.008801  0.005765  0.008568  0.000004
# 3     0.008287  0.009992  0.008226  0.008438  0.004863  0.008405  0.000000
# 4     0.008161  0.006190  0.008314  0.008670  0.004502  0.007555  0.000004
# ...        ...       ...       ...       ...       ...       ...       ...
# 1897  0.007373  0.007146  0.005407  0.006873  0.007216  0.006284  0.002566
# 1898  0.006639  0.006948  0.005713  0.006766  0.007211  0.005894  0.002580
# 1899  0.006661  0.006770  0.005296  0.007040  0.007019  0.006107  0.002549
# 1900  0.006770  0.006386  0.004637  0.006899  0.006374  0.006486  0.002308
# 1901  0.007100  0.006584  0.003871  0.006950  0.005829  0.006823  0.002549
#
# [1902 rows x 100 columns]
